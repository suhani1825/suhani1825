# %% [markdown]
# <a href="https://colab.research.google.com/github/suhani1825/suhani1825/blob/main/practical_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_excel("/content/Book1.xlsx")
data
# Out:
#    NO     Name Class  Marks
# 0   1   sanika  SYIT     80
# 1   2    mansi  SYIT     60
# 2   3   suhani  SYCS     85
# 3   4   rupesh  SYIT     75
# 4   5   vedant  SYCS     65
# 5   6    aditi  SYCS     90
# 6   7    omkar  SYIT     67
# 7   8   sakshi  SYIT     80
# 8   9  vaibhav  SYCS     60
# 9  10   ramesh  SYCS     60

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("/content/radhakrishna.jpg")
plt.imshow(img)

# %% [markdown]
# Aim:Summarizing data with statistics

# %%
import pandas as pd
df=pd.DataFrame({"Rollno":[1,1,3,4,5],
                 "Name":["sanika","sanika","aditi","mansi","sakshi"],
                 "Marks":[50,50,90,31,35],
                 "Class":["A","B","A","B","A"]})

print(df)
# Out:
#    Rollno    Name  Marks Class
# 0       1  sanika     50     A
# 1       1  sanika     50     B
# 2       3   aditi     90     A
# 3       4   mansi     31     B
# 4       5  sakshi     35     A

# %%
df.isnull().sum()
# Out:
# Rollno    0
# Name      0
# Marks     0
# Class     0
# dtype: int64

# %%
df.value_counts()
# Out:
# Rollno  Name    Marks  Class
# 1       sanika  50     A        1
#                        B        1
# 3       aditi   90     A        1
# 4       mansi   31     B        1
# 5       sakshi  35     A        1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rollno  5 non-null      int64
#  1   Name    5 non-null      object
#  2   Marks   5 non-null      int64
#  3   Class   5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 288.0+ bytes

# %%
df.describe()
# Out:
#          Rollno      Marks
# count  5.000000   5.000000
# mean   2.800000  71.000000
# std    1.788854  19.493589
# min    1.000000  50.000000
# 25%    1.000000  50.000000
# 50%    3.000000  80.000000
# 75%    4.000000  85.000000
# max    5.000000  90.000000

# %%
df.describe(include="object")
# Out:
#           Name Class
# count        5     5
# unique       4     2
# top     sanika     A
# freq         2     3

# %%
df.nunique()
# Out:
# Rollno    4
# Name      4
# Marks     4
# Class     2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(['Name']).sum()
# Out:
# 1

# %%
df['Name'].value_counts()
# Out:
# sanika    2
# aditi     1
# mansi     1
# sakshi    1
# Name: Name, dtype: int64

# %%
df['Name'].unique()
# Out:
# array(['sanika', 'aditi', 'mansi', 'sakshi'], dtype=object)

# %%
df['Class'].nunique()
# Out:
# 2

# %%
df['Class'].value_counts()
# Out:
# A    3
# B    2
# Name: Class, dtype: int64

# %%
df['Marks'].mean()
# Out:
# 51.2

# %%
df['Marks'].var()
# Out:
# 544.7

# %%
correalation=df.corr()
correalation
# Out:
# <ipython-input-98-8ba7e3f4e6ce>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correalation=df.corr()
#           Rollno     Marks
# Rollno  1.000000 -0.286229
# Marks  -0.286229  1.000000

# %%
import seaborn as sns
sns.heatmap(correalation,annot=True,fmt=".3f",cmap="plasma")
# Out:
# <Axes: >
